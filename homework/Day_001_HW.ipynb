# %%
作業1：
請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
A: https://www.kaggle.com/ronitf/heart-disease-uci
1. 你選的這組資料為何重要
A: 對人類健康貢獻
2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
A: Medical Center , from patient
3. 蒐集而來的資料型態為何
A: 結構化：數值
4. 這組資料想解決的問題如何評估
A: 除了評估準確率 亦須使用回歸分析各參數是否存在與target相關

# %%
作業2：
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
A: 供需平衡與配對率，人與車地理分佈亦是重點。若是人少即需多行銷，車不足則需加誘因補充。分佈問題則需分析後給予獎勵導引車到多人區域與時段。
2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
A: 來自叫車系統與APP後台。分區分時叫車數與對應車輛數量分佈。併計入平均單案結案時間影響。短程多時段車數需求較低。結帳金額。
3. 蒐集而來的資料型態為何
A: 結構化：數值
4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
A: 使用回歸分析各參數如人車比在各區與時段與收入關係 在行銷與配對獎勵引導後與預期是否為正向

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(obs_val, prid_val):
    """
    MSE
    Args:
        - obs_val: 實際值
        - prid_val: 預測值
    Return:
        - MSE
    """
    return (sum((obs_val - prid_val)**2) / len(obs_val))

# %%
def mean_absolute_error(obs_val, prid_val):
    """
    MAE
    Args:
        - obs_val: 實際值
        - prid_val: 預測值
    Return:
        - MAE
    """
    return (sum(abs(obs_val - prid_val)) / len(obs_val))

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 191.318
# The Mean absolute error is 11.163
